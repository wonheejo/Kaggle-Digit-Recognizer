# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
sns.set()
from tensorflow.python.client import device_lib
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential, load_model
from keras.layers import Dense, Dropout, Flatten, Lambda, Convolution2D, MaxPool2D
from keras.utils.np_utils import to_categorical
from keras.layers.normalization import BatchNormalization
from keras.optimizers import Adam, RMSprop
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import EarlyStopping, LearningRateScheduler, ReduceLROnPlateau, ModelCheckpoint
from keras import backend as K

from sklearn.model_selection import train_test_split
# Out:
# Using TensorFlow backend.

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID" # see issue #152
os.environ["CUDA_VISIBLE_DEVICES"]="0" # Will use only the first GPU device

# %%
tf.__version__
# Out:
# '2.1.0'

# %%
keras.__version__
# Out:
# '2.2.4-tf'

# %%
train = pd.read_csv('train.csv')
test = pd.read_csv('test.csv')

# %%
train.shape
# Out:
# (42000, 785)

# %%
test.shape
# Out:
# (28000, 784)

# %%
y_train = train['label']
x_train = train.drop(labels=['label'], axis=1)
x_train = x_train / 255.0
x_test = test / 255.0
x_train = x_train.values.reshape(-1, 28, 28, 1)
x_test = x_test.values.reshape(-1, 28, 28, 1)
y_train = to_categorical(y_train, num_classes = 10)

# %%
x_train.shape
# Out:
# (42000, 28, 28, 1)

# %%
x_test.shape
# Out:
# (28000, 28, 28, 1)

# %%
plt.title(y_train[200])
plt.plot(y_train[200])
plt.xticks(range(10));
plt.show()
# Out:
# c:\users\wonhee\anaconda3\envs\tensorgpu211\lib\site-packages\matplotlib\text.py:1150: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if s != self._text:

# %%
X = x_train
y = y_train
X_train2, X_val2, y_train2, y_val2 = train_test_split(x_train, y_train, test_size=0.10, random_state = 42)

# %%
with tf.device("/device:GPU:0"):
    def cnn_model():
        model = Sequential([
            Convolution2D(filters=32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
            BatchNormalization(),
            Convolution2D(filters=32, kernel_size=(3, 3), activation='relu'),
            BatchNormalization(),
            Convolution2D(filters=32, kernel_size=(5, 5), strides=2, padding='same', activation='relu'),
            BatchNormalization(),
            Dropout(0.4),
            
            Convolution2D(filters=64, kernel_size=(3, 3), activation='relu'),
            BatchNormalization(),
            Convolution2D(filters=64, kernel_size=(3, 3), activation='relu'),
            BatchNormalization(),
            Convolution2D(filters=64, kernel_size=(5, 5), strides=2, padding='same', activation='relu'),
            BatchNormalization(),
            Dropout(0.4),
            
            Convolution2D(filters=128, kernel_size=(4, 4), padding='same', activation='relu'),
            BatchNormalization(),
            Flatten(),
            Dense(256, activation='relu'),
            Dropout(0.4),
            Dense(10, activation='softmax')
        ])

        model.compile(optimizer=Adam(lr=0.0025), loss='categorical_crossentropy', metrics=['accuracy'])

        return model

# %%
cnn_model = cnn_model()
cnn_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 26, 32)        320
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 26, 26, 32)        128
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 24, 24, 32)        9248
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 24, 24, 32)        128
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 12, 12, 32)        25632
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 12, 12, 32)        128
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 10, 10, 64)        18496
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 8, 8, 64)          36928
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 8, 8, 64)          256
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 4, 4, 64)          102464
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 4, 4, 64)          256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 4, 4, 64)          0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 4, 4, 128)         131200
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 4, 4, 128)         512
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 256)               524544
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 256)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                2570
# =================================================================
# Total params: 853,066
# Trainable params: 852,234
# Non-trainable params: 832
# _________________________________________________________________

# %%
def exponential_decay(epochs):
    def exponential_decay_fn(lr, s):
        return lr * 0.95**(epochs/20)
    return exponential_decay_fn

# %%
epochs=100
learning_rate_reduction = LearningRateScheduler(lambda x: 1e-3 * 0.95 ** x)
learning_rate_reduction2 = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=4, min_lr=0.00001)
checkpoint_cb = ModelCheckpoint('best_model_checkpoint.h5', save_best_only=True)
early_stopping = EarlyStopping(patience=10, restore_best_weights=True)

# %%
gen = ImageDataGenerator(rotation_range=10, width_shift_range=0.1, shear_range=0.3, height_shift_range=0.1, zoom_range=0.1)
batch_size = 64
batches = gen.flow(X_train2, y_train2, batch_size=batch_size)
history=cnn_model.fit_generator(generator=batches, steps_per_epoch=X_train2.shape[0]//batch_size, validation_data = (X_val2, y_val2), epochs=epochs, callbacks=[checkpoint_cb, early_stopping, learning_rate_reduction])
# Out:
# Epoch 1/100
# 590/590 [==============================] - 12s 20ms/step - loss: 0.4617 - accuracy: 0.8554 - val_loss: 0.2167 - val_accuracy: 0.9255
# Epoch 2/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.1436 - accuracy: 0.9582 - val_loss: 0.0592 - val_accuracy: 0.9819
# Epoch 3/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.1125 - accuracy: 0.9677 - val_loss: 0.0342 - val_accuracy: 0.9893
# Epoch 4/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0982 - accuracy: 0.9718 - val_loss: 0.0378 - val_accuracy: 0.9898
# Epoch 5/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0819 - accuracy: 0.9773 - val_loss: 0.0575 - val_accuracy: 0.9819
# Epoch 6/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0752 - accuracy: 0.9786 - val_loss: 0.0420 - val_accuracy: 0.9886
# Epoch 7/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0700 - accuracy: 0.9805 - val_loss: 0.0285 - val_accuracy: 0.9912
# Epoch 8/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0613 - accuracy: 0.9822 - val_loss: 0.0360 - val_accuracy: 0.9888
# Epoch 9/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0591 - accuracy: 0.9835 - val_loss: 0.0320 - val_accuracy: 0.9900
# Epoch 10/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0551 - accuracy: 0.9847 - val_loss: 0.0274 - val_accuracy: 0.9919
# Epoch 11/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0498 - accuracy: 0.9859 - val_loss: 0.0236 - val_accuracy: 0.9938
# Epoch 12/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0468 - accuracy: 0.9868 - val_loss: 0.0179 - val_accuracy: 0.9952
# Epoch 13/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0397 - accuracy: 0.9892 - val_loss: 0.0314 - val_accuracy: 0.9919
# Epoch 14/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0403 - accuracy: 0.9881 - val_loss: 0.0236 - val_accuracy: 0.9931
# Epoch 15/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0369 - accuracy: 0.9894 - val_loss: 0.0210 - val_accuracy: 0.9931
# Epoch 16/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0391 - accuracy: 0.9889 - val_loss: 0.0244 - val_accuracy: 0.9926
# Epoch 17/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0342 - accuracy: 0.9904 - val_loss: 0.0290 - val_accuracy: 0.9926
# Epoch 18/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0328 - accuracy: 0.9909 - val_loss: 0.0223 - val_accuracy: 0.9933
# Epoch 19/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0294 - accuracy: 0.9915 - val_loss: 0.0174 - val_accuracy: 0.9938
# Epoch 20/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0275 - accuracy: 0.9923 - val_loss: 0.0274 - val_accuracy: 0.9924
# Epoch 21/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0261 - accuracy: 0.9919 - val_loss: 0.0196 - val_accuracy: 0.9933
# Epoch 22/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0264 - accuracy: 0.9930 - val_loss: 0.0177 - val_accuracy: 0.9940
# Epoch 23/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0230 - accuracy: 0.9929 - val_loss: 0.0211 - val_accuracy: 0.9950
# Epoch 24/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0256 - accuracy: 0.9926 - val_loss: 0.0192 - val_accuracy: 0.9948
# Epoch 25/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0238 - accuracy: 0.9926 - val_loss: 0.0165 - val_accuracy: 0.9950
# Epoch 26/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0221 - accuracy: 0.9933 - val_loss: 0.0164 - val_accuracy: 0.9952
# Epoch 27/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0204 - accuracy: 0.9940 - val_loss: 0.0157 - val_accuracy: 0.9948
# Epoch 28/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0209 - accuracy: 0.9939 - val_loss: 0.0193 - val_accuracy: 0.9943
# Epoch 29/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0204 - accuracy: 0.9943 - val_loss: 0.0173 - val_accuracy: 0.9943
# Epoch 30/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0183 - accuracy: 0.9945 - val_loss: 0.0181 - val_accuracy: 0.9950
# Epoch 31/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0189 - accuracy: 0.9942 - val_loss: 0.0151 - val_accuracy: 0.9950
# Epoch 32/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0161 - accuracy: 0.9950 - val_loss: 0.0148 - val_accuracy: 0.9955
# Epoch 33/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0158 - accuracy: 0.9952 - val_loss: 0.0163 - val_accuracy: 0.9945
# Epoch 34/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0168 - accuracy: 0.9949 - val_loss: 0.0176 - val_accuracy: 0.9948
# Epoch 35/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0157 - accuracy: 0.9954 - val_loss: 0.0178 - val_accuracy: 0.9948
# Epoch 36/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0143 - accuracy: 0.9949 - val_loss: 0.0154 - val_accuracy: 0.9945
# Epoch 37/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0145 - accuracy: 0.9957 - val_loss: 0.0152 - val_accuracy: 0.9952
# Epoch 38/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0135 - accuracy: 0.9960 - val_loss: 0.0151 - val_accuracy: 0.9952
# Epoch 39/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0127 - accuracy: 0.9962 - val_loss: 0.0183 - val_accuracy: 0.9948
# Epoch 40/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0129 - accuracy: 0.9966 - val_loss: 0.0175 - val_accuracy: 0.9950
# Epoch 41/100
# 590/590 [==============================] - 10s 16ms/step - loss: 0.0119 - accuracy: 0.9962 - val_loss: 0.0170 - val_accuracy: 0.9948
# Epoch 42/100
# 590/590 [==============================] - 9s 16ms/step - loss: 0.0133 - accuracy: 0.9962 - val_loss: 0.0152 - val_accuracy: 0.9952

# %%
cnn_model.save('CNN 2x2 2x2 1x1 epoch35 batch64 lr0.0025 0220.h5')

# %%
cnn_model_final = keras.models.load_model('best_model_checkpoint.h5')

# %%
cnn_history = history.history
pd.DataFrame(cnn_history).plot(figsize=(10, 9))
plt.grid(True)
plt.gca().set_ylim(0, 1)
plt.show()

# %%
cnn_history.keys()
# Out:
# dict_keys(['val_loss', 'val_accuracy', 'loss', 'accuracy', 'lr'])

# %%
losses = cnn_history['loss']
val_losses = cnn_history['val_loss']
epochs = range(1, len(val_losses)+1)
fig = plt.subplots(figsize=(15, 10))
plt.plot(epochs, losses, 'bo')
plt.plot(epochs, val_losses, 'b+')
plt.xlabel('Epoches')
plt.ylabel('Losses')
plt.ylim(0, 1)
# Out:
# (0, 1)

# %%
lr = cnn_history['lr']
fig = plt.subplots(figsize=(15, 10))
plt.plot(epochs, lr)
plt.xlabel('Epochs')
plt.ylabel('Learning rate')
plt.ylim(0, 0.01)
# Out:
# (0, 0.01)

# %%
accuracy = cnn_history['accuracy']
val_accuracy = cnn_history['val_accuracy']
epochs = range(1, len(val_losses)+1)
fig = plt.subplots(figsize=(15, 10))
sns.lineplot(epochs, accuracy, label='accuracy' )
sns.lineplot(epochs, val_accuracy, label='val_accuracy')
plt.ylim(0.9, 1)
plt.xlabel('Epoches')
plt.ylabel('Accuracy')
plt.legend(loc='best')

# %%
finalmodels = cnn_model.predict(x_test)
results = np.argmax(finalmodels, axis=1)
results = pd.Series(results, name='label')

# %%
submissions = pd.concat([pd.Series(range(1, 28001), name='ImageId'), results], axis=1)
submissions.to_csv("submissionCNN22221112843.csv", index=False, header=True)
